# %%
def greet():
    print("Hello")

greet()
greet()
# Out:
# Hello
# Hello

# %%
def greet(name, name2):
    print("Hello", name, name2)
greet("Kai", "Kaia")
greet("Vi", "Cait")
# Out:
# Hello Kai Kaia
# Hello Vi Cait

# %%
# Return values
def multiply(x, y):
    return x*y
    
answer = multiply(26,45)
print(answer)
# Out:
# 1170

# %%
from math import sqrt # Implemented build-in-module
sqrt(36)
# Out:
# 6.0

# %%
#From the file untitled.py

import untitled 
untitled.hello()
# Out:
# Hi
