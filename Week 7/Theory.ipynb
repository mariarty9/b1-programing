# %%
# Open function
file_objcet = open(filename, mode)
'r' - Read mode
'w' - Write Mode
'a' - Append mode
'rb/wb' - Binary

# %%
import os
file = input("Filename:")

#validate the filename
if ".." in file or file.startswitch("/"):
    raise ValueError("Unsafe Filename:")

#Construst safe pathwithtin allowed directory
safe_path = os.path

# %%
#Reading an entire file
with open("data.txt", "r") as f:
    for line in f:
        print(line.strip())

# %%
#Writing content to files
with open("output.txt", "w") as f:  #Creates the file if it is not existing
    f.write("Hello world! \n")
    f.write("This is a new line. \n")
    f.write("Writing this in Python. \n")

# %%
with open ("output.txt", "a") as f:
    f.write("New log entry \n")

# %%
#Cyber Angle
Always use Append-Only Modes

# %%
with open ("data.txt", "r") as f:
    content = f.read()

# %%
#try/ecept foundation
try:
    result = 10/0 # 0 results failure any other number - not
    print(f"Result: {result}")
except ZeroDivisionError:
    print("Cannot divide by zero")
    result = None
# Out:
# Cannot divide by zero

# %%
#Intro to Logging
'Level of logging'
DEBUG
INFO
WARNING
ERROR
CRITICAL

# %%
import logging

logging.basicConfig(
    level = logging.INFO,
    format = '%(levelmname)s - %(message)s'
)

logging.debug("Detailed debug information.")
logging.info("Application started.")
logging.warning("API rate limit approaching: 95% of quota used.")
logging.error("Payment processing failed.")

# %%
#Anatomy of log entry
2024-03-14 10:02:11 - app.auth - INFO - User login successful: user_id = 847
